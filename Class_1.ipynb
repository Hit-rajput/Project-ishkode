# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
dt=pd.read_csv('Class_1.csv')

# %%
dt['newpleas'].describe()
# Out:
# count       100
# unique       29
# top       39.00
# freq         11
# Name: newpleas, dtype: object

# %%
dt['newpleas'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: newpleas, Length: 100, dtype: bool

# %%
plt.hist(dt['newpleas'])
# Out:
# (array([24., 13., 23.,  7.,  4.,  4.,  5.,  7., 10.,  3.]),
#  array([ 0. ,  2.8,  5.6,  8.4, 11.2, 14. , 16.8, 19.6, 22.4, 25.2, 28. ]),
#  <BarContainer object of 10 artists>)
